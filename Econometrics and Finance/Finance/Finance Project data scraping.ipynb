# %% [markdown]
# **AGRICULTURE ----> 1. Goodricke Group Ltd(GOODRICKE.BO) 2. BOMBAY BURMAH(BBTC.BO)
# PHARMACY ----> 1. PharmaCyte Biotech(PMCB) 2. DR. REDDY S LABORATORIES(RDY)
# BANKING ----> 1. STATE BANK OF INDIA(SBIN.NS) 2. HDFC BANK(HDB)
# IT SECTOR ----> 1. Infosys Ltd.(INFY) 2. Wipro Ltd.(WIT)**
# REAL ESTATE ----> 1. DLF(DLF) 2. Oberoi Realty(OBEROIRLTY)
# ENERGY ----> 1. Shell plc(SHEL) 2. Phillips 66(PSX)
# COMUNICATION SERVICE ----> 1. Netflix Inc.(NFLX) 2. Alphabet Inc.(GOOGL)
# CONSUMER CYCLICAL ----> 1. Amazon(AMZN) 2. McDonald's(MCD)
# CONSUMER DEFENSIVE ----> 1. Walmart Inc.(WMT) 2. Unilever PLC(UL)
# FINANCIAL SERVICE ----> 1. Visa(V) 2. JPMorgan Chase & Co.(JPM)
# **HEALTHCARE ----> 1. Johnson & Johnson(JNJ) 2. AbbVie Inc.(ABBV)**
# INDUSTRIALS ----> 1. Caterpillar Inc.(CAT) 2. Union Pacific Corporation(UNP)
# UTILITIES ----> 1. NextEra Energy, Inc.(NEE-PR) 2. Duke Energy Corporation(DUK)
# **TECHNOLOGY ----> 1. Microsoft Corporation(MSFT) 2. NVIDIA (NVDA)**

# %%
import numpy as np
import pandas as pd
import yfinance as yf

# %%
# The ticker symbol for the Crude Oil stock 
ticker = "WIT"

# Get the stock data for the past year, with daily frequency
stock_data = yf.download(ticker, start="2021-08-01", end="2023-08-29", keepna = True)
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
stock_data
# Out:
#             Open  High   Low  Close  Adj Close   Volume
# Date
# 2021-08-02  8.40  8.47  8.39   8.40   8.295673   957200
# 2021-08-03  8.48  8.58  8.48   8.57   8.463563  1516900
# 2021-08-04  8.56  8.56  8.47   8.53   8.424061  1716100
# 2021-08-05  8.56  8.59  8.55   8.57   8.463563  1113100
# 2021-08-06  8.52  8.56  8.45   8.48   8.374681  1315400
# ...          ...   ...   ...    ...        ...      ...
# 2023-08-22  4.96  5.00  4.96   4.99   4.990000  1544200
# 2023-08-23  5.00  5.09  5.00   5.09   5.090000  1396700
# 2023-08-24  4.99  5.02  4.95   4.95   4.950000  1650800
# 2023-08-25  4.94  4.99  4.93   4.98   4.980000  1233500
# 2023-08-28  4.96  4.99  4.96   4.97   4.970000   974600
#
# [522 rows x 6 columns]

# %%
stock_data.to_csv("C:\\Users\\SOUMYADEEP SADHUKHAN\\Documents\\BDA\\3rd Sem\\Finance\\Wipro.csv", header = True)
